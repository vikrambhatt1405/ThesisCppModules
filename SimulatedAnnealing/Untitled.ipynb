# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
sns.set_style("darkgrid")

# %%
x=[]
with open("out.txt",'r') as f:
    for line in f:
        x.append(float(line))
plt.plot(x)
